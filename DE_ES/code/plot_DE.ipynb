# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Interpolation for 128 var

# %%
random_seed = [(19521281 + i) for i in range(10)]
x_128 = []
y_128 = []
for seed in random_seed:
  data = pd.read_csv('{}.csv'.format(seed))
  data.drop(data.columns[[0]], axis=1, inplace=True)
  data.columns = ['best_fitness', 'num_calls']
  x_128.append(list(data['num_calls']))
  y_128.append(list(data['best_fitness']))

# %%
def interpolation_128_var(num_calls, best_fitness, num_variable):
  x = [i for i in range(0, 30001 if num_variable == 2 else 500001, 100*num_variable)]
  y = []
  std_y = []

  temp_y = []
  for i in range(10):
    temp_y.append(np.interp(x, num_calls[i], best_fitness[i]))
  y.append(temp_y)

  final_y = []
  final_x = [x]
  for _ in range(1):
    y_ = []
    for i in range(len(y[_][0])):
      sum_ = 0
      for j in range(len(y[_])):
        sum_ += y[_][j][i]

      sum_ /= 10
      y_.append(sum_)  

    final_y.append(y_)
    std_y.append(np.std(np.array(y_), axis=0))

  return final_x, final_y, std_y

# %%
x1, y1, error_1 = interpolation_128_var(num_calls=x_128, best_fitness=y_128, num_variable=2)
x1 = np.array(x1).ravel()
y1 = np.array(y1).ravel()

# %%
print(x1)
# Out:
# [    0  2000  4000  6000  8000 10000 12000 14000 16000 18000 20000 22000
#  24000 26000 28000 30000 32000 34000 36000 38000 40000 42000 44000 46000
#  48000 50000 52000 54000 56000 58000 60000]

# %% [markdown]
# #Interpolation for 1024 var

# %%
random_seed = [(19521281 + i) for i in range(10)]
x_1024 = []
y_1024 = []
for seed in random_seed:
  data = pd.read_csv('{}.csv'.format(seed))
  data.drop(data.columns[[0]], axis=1, inplace=True)
  data.columns = ['best_fitness', 'num_calls']
  x_1024.append(list(data['num_calls']))
  y_1024.append(list(data['best_fitness']))

# %%
def interpolation_1024_var(num_calls, best_fitness, num_variable):
  x = [i for i in range(0, 30001 if num_variable == 2 else 500001, 100*num_variable)]
  y = []
  std_y = []

  temp_y = []
  for i in range(10):
    temp_y.append(np.interp(x, num_calls[i], best_fitness[i]))
  y.append(temp_y)

  final_y = []
  final_x = [x]
  for _ in range(1):
    y_ = []
    for i in range(len(y[_][0])):
      sum_ = 0
      for j in range(len(y[_])):
        sum_ += y[_][j][i]

      sum_ /= 10
      y_.append(sum_)  

    final_y.append(y_)
    std_y.append(np.std(np.array(y_), axis=0))

  return final_x, final_y, std_y

# %%
x2, y2, error_2 = interpolation_1024_var(num_calls=x_1024, best_fitness=y_1024, num_variable=2)
x2 = np.array(x2).ravel()
y2 = np.array(y2).ravel()

# %%
print(x2)
# Out:
# [    0  2000  4000  6000  8000 10000 12000 14000 16000 18000 20000 22000
#  24000 26000 28000 30000 32000 34000 36000 38000 40000 42000 44000 46000
#  48000 50000 52000 54000 56000 58000 60000]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Draw graph for DE

# %%
figure = plt.figure(figsize=(10,5))
plt.rcParams["font.size"] = 18

axes = plt.subplot(111)
axes.plot(x1, y1, "b-", color = 'OliveDrab', label = 'DE with n=128')
axes.fill_between(x1 , y1 + error_1, y1 - error_1, color = 'OliveDrab', alpha = 0.2)
axes.plot(x2 , y2, "g-", color = 'Salmon', label = 'DE with n=1024')
axes.fill_between(x2, y2 + error_2, y2 - error_2, color = 'Salmon', alpha = 0.2)


axes.tick_params(axis="both", which="major",direction="in",length=5,width=2,top="on",right="on")
axes.tick_params(axis="both", which="minor",direction="in",length=2,width=1,top="on",right="on")

axes.set_title("Ackley with d=2 ")
axes.set_xlabel("Num of evaluation calls")
axes.set_ylabel("Objective function")

axes.grid()
plt.legend(loc = 'best')
plt.show()


figure.savefig("Ackley_DE_2.jpg",format="jpg", dpi=300)

# %%
figure = plt.figure(figsize=(10,5))
plt.rcParams["font.size"] = 18

axes = plt.subplot(111)
axes.plot(x1, y1, "b-", color = 'Peru', label = 'DE with n=128')
axes.fill_between(x1 , y1 + error_1, y1 - error_1, color = 'Peru', alpha = 0.2)
axes.plot(x2 , y2, "g-", color = 'Cyan', label = 'DE with n=1024')
axes.fill_between(x2, y2 + error_2, y2 - error_2, color = 'Cyan', alpha = 0.2)


axes.tick_params(axis="both", which="major",direction="in",length=5,width=2,top="on",right="on")
axes.tick_params(axis="both", which="minor",direction="in",length=2,width=1,top="on",right="on")

axes.set_title("Griewank with d=2 ")
axes.set_xlabel("Num of evaluation calls")
axes.set_ylabel("Objective function")

axes.grid()
plt.legend(loc = 'best')
plt.show()


figure.savefig("Griewank_DE_2.jpg",format="jpg", dpi=300)

# %%
figure = plt.figure(figsize=(10,5))
plt.rcParams["font.size"] = 18

axes = plt.subplot(111)
axes.plot(x1, y1, "b-", color = 'Goldenrod', label = 'DE with n=128')
axes.fill_between(x1 , y1 + error_1, y1 - error_1, color = 'Goldenrod', alpha = 0.2)
axes.plot(x2 , y2, "g-", color = 'DarkSeaGreen', label = 'DE with n=1024')
axes.fill_between(x2, y2 + error_2, y2 - error_2, color = 'DarkSeaGreen', alpha = 0.2)


axes.tick_params(axis="both", which="major",direction="in",length=5,width=2,top="on",right="on")
axes.tick_params(axis="both", which="minor",direction="in",length=2,width=1,top="on",right="on")

axes.set_title("Rastrigin with d=2 ")
axes.set_xlabel("Num of evaluation calls")
axes.set_ylabel("Objective function")

axes.grid()
plt.legend(loc = 'best')
plt.show()


figure.savefig("Rastrigin_DE_2.jpg",format="jpg", dpi=300)

# %%
figure = plt.figure(figsize=(10,5))
plt.rcParams["font.size"] = 18

axes = plt.subplot(111)
axes.plot(x1, y1, "b-", color = 'OrangeRed', label = 'DE with n=128')
axes.fill_between(x1 , y1 + error_1, y1 - error_1, color = 'OrangeRed', alpha = 0.2)
axes.plot(x2 , y2, "g-", color = 'SteelBlue', label = 'DE with n=1024')
axes.fill_between(x2, y2 + error_2, y2 - error_2, color = 'SteelBlue', alpha = 0.2)


axes.tick_params(axis="both", which="major",direction="in",length=5,width=2,top="on",right="on")
axes.tick_params(axis="both", which="minor",direction="in",length=2,width=1,top="on",right="on")

axes.set_title("Rosenbrock with d=2 ")
axes.set_xlabel("Num of evaluation calls")
axes.set_ylabel("Objective function")

axes.grid()
plt.legend(loc = 'best')
plt.show()


figure.savefig("Rosenbrock_DE_2.jpg",format="jpg", dpi=300)

# %%
figure = plt.figure(figsize=(10,5))
plt.rcParams["font.size"] = 18

axes = plt.subplot(111)
axes.plot(x1, y1, "b-", color = 'Aquamarine', label = 'DE with n=128')
axes.fill_between(x1 , y1 + error_1, y1 - error_1, color = 'Aquamarine', alpha = 0.2)
axes.plot(x2 , y2, "g-", color = 'Gold', label = 'DE with n=1024')
axes.fill_between(x2, y2 + error_2, y2 - error_2, color = 'Gold', alpha = 0.2)


axes.tick_params(axis="both", which="major",direction="in",length=5,width=2,top="on",right="on")
axes.tick_params(axis="both", which="minor",direction="in",length=2,width=1,top="on",right="on")

axes.set_title("Sphere with d=2 ")
axes.set_xlabel("Num of evaluation calls")
axes.set_ylabel("Objective function")

axes.grid()
plt.legend(loc = 'best')
plt.show()


figure.savefig("Sphere_DE_2.jpg",format="jpg", dpi=300)
